# %%
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import json
import pandas as pd
import csv
import re #regular expression
from textblob import TextBlob
import string
import preprocessor as p

# %%
pip install tweepy

# %%
pip install preprocessor
# Out:
# ...
#   Created wheel for preprocessor: filename=preprocessor-1.1.3-cp37-none-any.whl size=4477 sha256=f4927621b2e70c80cb5bd012cdc060b707ec1f237cf41c1f70a8b7737bedc806
#   Stored in directory: /root/.cache/pip/wheels/98/c1/a2/21fbcfd80d76576bbf148991a66f00730f541f265c7600000f
# Successfully built preprocessor
# ...

# %%
api_key = 'kejkMQJ8Q3pcez2qvpv8bffnr'
api_secret = 'kLeS5amVLBY7Yg9SjCaCrAsOgrQMlHRr0EIKPmZSoT6QC9kEgN'
access_token = '282729361-0Ci5EqHfuJyYasizNFmBYfkI0ONbSq9XWKyt3PFG'
access_secret = 'kTR33jNeGJ7w524BdfdkKBqIHgACEKNeObXgyqR604PsM'
auth = OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth)

# %%
# Using the API object to get tweets from your timeline, and storing it in a variable called public_tweets
public_tweets = api.home_timeline()
# foreach through all tweets pulled
for tweet in public_tweets:
   # printing the text stored inside the tweet object
   print (tweet.text)
# Out:
# Hay una cñora 40tona muy desagradable por ahí, que ah! cómo le encanta andar pidiendo que cancelen gente en DM, per… https://t.co/m6RhGyeyW1
# RT @_NataliaLeon_: “Por títulos no se puede ver si un equipo es más grande que el otro... somos mucho más grandes que el @ClubAmerica” dice…
# Tonight on #AEWDynamite, Big Money Matt promises to begin the rebound from his financial woes.
#
# Matt Hardy’s financ… https://t.co/Pn68Co9Icx
# Por un aterrizaje forzoso, piloto estuvo perdido 36 días en el Amazonas; así fue su rescate https://t.co/zngrwIZpeL https://t.co/v8mJkrGdXy
# ¡SIGUE EN PLAN GRANDE! 🔥
#
# Iba a ser autogol de Verrati, pero Keylor Navas estuvo muy atento a primer palo para rech… https://t.co/jixf69nwDf
# “The penalty (decision) was incredible. I don’t understand it. Maybe one day they will explain the rule around VAR.… https://t.co/hsgJSuvpck
# ✅ El Liverpool tiene prácticamente asegurada su clasificación para cuartos de final de la Champions League
# https://t.co/GBvj3LZyMb
# ...

# %%
# The Twitter user who we want to get tweets from
name = "CocaColaMX"
# Number of tweets to pull
tweetCount = 100

# Calling the user_timeline function with our parameters
results = api.user_timeline(id=name, count=tweetCount)

# foreach through all tweets pulled
for tweet in results:
   # printing the text stored inside the tweet object
   print (tweet.text)

# %%
# The Twitter user who we want to get tweets from
name = "PepsiMEX"
# Number of tweets to pull
tweetCount = 100

# Calling the user_timeline function with our parameters
results = api.user_timeline(id=name, count=tweetCount)

# foreach through all tweets pulled
for tweet in results:
   # printing the text stored inside the tweet object
   print (tweet.text)

# %%
# The Twitter user who we want to get tweets from
name = "BimboMX"
# Number of tweets to pull
tweetCount = 100

# Calling the user_timeline function with our parameters
results = api.user_timeline(id=name, count=tweetCount)

# foreach through all tweets pulled
for tweet in results:
   # printing the text stored inside the tweet object
   print (tweet.text)

# %%
# The Twitter user who we want to get tweets from
name = "alpuraoficial"
# Number of tweets to pull
tweetCount = 100

# Calling the user_timeline function with our parameters
results = api.user_timeline(id=name, count=tweetCount)

# foreach through all tweets pulled
for tweet in results:
   # printing the text stored inside the tweet object
   print (tweet.text)

# %%
# The Twitter user who we want to get tweets from
name = "UnVasoDeLALA"
# Number of tweets to pull
tweetCount = 100

# Calling the user_timeline function with our parameters
results = api.user_timeline(id=name, count=tweetCount)

# foreach through all tweets pulled
for tweet in results:
   # printing the text stored inside the tweet object
   print (tweet.text)

# %%
# The Twitter user who we want to get tweets from
name = "LaModernaMX"
# Number of tweets to pull
tweetCount = 100

# Calling the user_timeline function with our parameters
results = api.user_timeline(id=name, count=tweetCount)

# foreach through all tweets pulled
for tweet in results:
   # printing the text stored inside the tweet object
   print (tweet.text)

# %%
# The Twitter user who we want to get tweets from
name = "LaCostenaMX"
# Number of tweets to pull
tweetCount = 100

# Calling the user_timeline function with our parameters
results = api.user_timeline(id=name, count=tweetCount)

# foreach through all tweets pulled
for tweet in results:
   # printing the text stored inside the tweet object
   print (tweet.text)

# %%
# The Twitter user who we want to get tweets from
name = "NescafeMX"
# Number of tweets to pull
tweetCount = 100

# Calling the user_timeline function with our parameters
results = api.user_timeline(id=name, count=tweetCount)

# foreach through all tweets pulled
for tweet in results:
   # printing the text stored inside the tweet object
   print (tweet.text)

# %%
# The Twitter user who we want to get tweets from
name = "KnorrMexico"
# Number of tweets to pull
tweetCount = 100

# Calling the user_timeline function with our parameters
results = api.user_timeline(id=name, count=tweetCount)

# foreach through all tweets pulled
for tweet in results:
   # printing the text stored inside the tweet object
   print (tweet.text)

# %%
# The Twitter user who we want to get tweets from
name = "vivenutri"
# Number of tweets to pull
tweetCount = 100

# Calling the user_timeline function with our parameters
results = api.user_timeline(id=name, count=tweetCount)

# foreach through all tweets pulled
for tweet in results:
   # printing the text stored inside the tweet object
   print (tweet.text)

# %%
class MyListener(StreamListener):

  def on_data(self, data):
    try:
      with open('Scraping_Twitter.csv', 'a') as f:
        f.write(data)
        return True
    except BaseException as e:
      print("Error en el dato: %s" % str(e))
    return True

  def on_error(self, status):
    print(status)
    return True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
twitter_stream = Stream(auth = api.auth, listener = MyListener())
twitter_stream.filter(track=['#CocaCola', '#TeamCocaCola', '#Pepsi', '#PEPSI', '#pepsi', '#TeamPepsi', '#Bimbo', '#Lala', '#NutriLeche', 
                             '#LaModerna', '#Alpura', '#LaCosteña', '#Nescafé', '#Knorr', '#Cloralex', '#cloralex', '#Colgate', '#DelMonte', 
                             '#delmonte', '#RedCola', 'CocaColaMX', 'PepsiMEX', 'BimboMX', 'alpuraoficial', 'UnVasoDeLALA', 'LaModernaMX',
                             'LaCostenaMX', 'NescafeMX', 'KnorrMexico', 'RedColaOficial', '@CocaColaMX', '@PepsiMEX', '@BimboMX', '@alpuraoficial',
                             '@UnVasoDeLALA', '@LaModernaMX', '@LaCostenaMX', '@NescafeMX', '@KnorrMexico', '@RedColaOficial'])
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/urllib3/response.py in _error_catcher(self)
#     361             try:
# --> 362                 yield
#     363
#
# /usr/local/lib/python3.7/dist-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     443                 cache_content = False
# --> 444                 data = self._fp.read(amt)
#     445                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#
# /usr/lib/python3.7/http/client.py in read(self, amt)
#     460             b = bytearray(amt)
# --> 461             n = self.readinto(b)
#     462             return memoryview(b)[:n].tobytes()
#
# /usr/lib/python3.7/http/client.py in readinto(self, b)
#     494         if self.chunked:
# --> 495             return self._readinto_chunked(b)
#     496
#
# ...

# %%
twitter_stream = Stream(auth = api.auth, listener = MyListener())
twitter_stream.filter(track=['#TeamCocaCola'])

# %%
twitter_stream = Stream(auth = api.auth, listener = MyListener())
twitter_stream.filter(track=['#Pepsi'])

# %%
twitter_stream = Stream(auth = api.auth, listener = MyListener())
twitter_stream.filter(track=['#PEPSI'])

# %%
twitter_stream = Stream(auth = api.auth, listener = MyListener())
twitter_stream.filter(track=['#TeamCocaCola', '#Pepsi', '#PEPSI', '#pepsi', '#TeamPepsi', '#Bimbo', '#Lala', '#NutriLeche', 
                             '#LaModerna', '#Alpura', '#LaCosteña', '#Nescafé', '#Knorr', '#Cloralex', '#cloralex', '#Colgate', '#DelMonte', 
                             '#delmonte', '#RedCola', 'CocaColaMX', 'PepsiMEX', 'BimboMX', 'alpuraoficial', 'UnVasoDeLALA', 'LaModernaMX',
                             'LaCostenaMX', 'NescafeMX', 'KnorrMexico', 'RedColaOficial', '@CocaColaMX', '@PepsiMEX', '@BimboMX', '@alpuraoficial',
                             '@UnVasoDeLALA', '@LaModernaMX', '@LaCostenaMX', '@NescafeMX', '@KnorrMexico', '@RedColaOficial'])

# %%
scraping_twitter = pd.read_csv('/content/Scraping_Twitter.csv')

# %%
scraping_twitter.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...
